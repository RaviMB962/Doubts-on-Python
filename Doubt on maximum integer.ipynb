# %%
d = {"india": "IN",
    "canada": "CA",
    "china": "CH",
    "united state": "US"}

# %%
"india" in d
# Out:
# True

# %%
for i in d:
    print(i)
# Out:
# india
# canada
# china
# united state

# %%
l_greater = []
l_smaller = []
for i in d:
    if len(i)<=5:
        l_smaller.append(i)
    else:
        l_greater.append(i)

# %%
l_greater
# Out:
# ['canada', 'united state']

# %%
l_smaller
# Out:
# ['india', 'china']

# %%
e = {"ineuron":{
    "a": 14,
    "b" : 10,
    "c": 4
    
},
  "course":    {'d': 45,
                  'e': 34,
                  'f': 1
      }
      }

# %%
for i in e.values():
    print(i)
# Out:
# {'a': 14, 'b': 10, 'c': 4}
# {'d': 45, 'e': 34, 'f': 1}

# %%
for i in e.values():
    for j in i.values():
        print(j)
# Out:
# 14
# 10
# 4
# 45
# 34
# 1

# %%
lst = []
for i in e.values():
    for j in i.values():
        lst.append(j)
    print(max(lst))
# Out:
# 14
# 45

# %%
#printing maximum values
e =  {"ineuron": {"a": 14, "b": 10, "c": 4},
     "course": {"d": 45, "e": 34, "f": 1}}

for i in e.values():
    
    mx = 0
    for j in i.values():
        if mx<j:
            mx=j
    print(mx)
# Out:
# 14
# 45

# %%
for i in e.values():
    print(max(i.values()))
# Out:
# 14
# 45

# %%
e
# Out:
# {'ineuron': {'a': 14, 'b': 10, 'c': 4}, 'course': {'d': 45, 'e': 34, 'f': 1}}

# %%
for i in e.keys():
    print(i)
    print(max(e[i].values()))
# Out:
# ineuron
# 14
# course
# 45

# %%
#printing maximum values
e =  {"ineuron": {"a": 10, "b": 20, "c": 4},
     "course": {"d": 15, "e": 34, "f": 55}}

for i in e.values():
    
    mx = 0
    for j in i.values():
        if mx<j:
            mx=j
    print(mx)
# Out:
# 20
# 55

# %%
r =  {"ineuron": {"a": 10, "b": 20, "c": 4}, "course": {"d": 15, "e": 34, "f": 55}, 
      "g": 34, "h": [45, 6, 7, 8,9, 3], "i" : (45, 34,2), 'k': "ravi"}

# %%
for i in r.values():
    print(i)
# Out:
# {'a': 10, 'b': 20, 'c': 4}
# {'d': 15, 'e': 34, 'f': 55}
# 34
# [45, 6, 7, 8, 9, 3]
# (45, 34, 2)
# ravi

# %%
lst[]
for i in r.values():
    for j in i.values():
        lst.append(j)
        print(lst[])
# Out:
#   File "<ipython-input-61-449316d08f71>", line 1
#     lst[]
#         ^
# SyntaxError: invalid syntax

# %%
r
# Out:
# {'ineuron': {'a': 10, 'b': 20, 'c': 4},
#  'course': {'d': 15, 'e': 34, 'f': 55},
#  'g': 34,
#  'h': [45, 6, 7, 8, 9, 3],
#  'i': (45, 34, 2),
#  'k': 'ravi'}

# %%
##maximum integer
l1 = []
for i in r:
    if type(r[i]) == int:
        l1.append(r[i])
    elif type (r[i]) == str:
        continue
    elif type (r[i]) == dict:
        l1.extend(list(d[i].values()))
    else:
        l1.extend(list(d[i]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-b0faf47b2938> in <module>
#       8         continue
#       9     elif type (r[i]) == dict:
# ---> 10         l1.extend(list(d[i].values()))
#      11     else:
#      12         l1.extend(list(d[i]))
#
# KeyError: 'ineuron'
