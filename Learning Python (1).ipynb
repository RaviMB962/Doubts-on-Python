# %%
l2 =['xyz', 'pqr', 2535, 6+5j]
l2
# Out:
# ['xyz', 'pqr', 2535, (6+5j)]

# %%
l2.append(2323)

# %%
l2
# Out:
# ['xyz', 'pqr', 2535, (6+5j), 2323]

# %%
l2.pop()
# Out:
# 2323

# %%
l2
# Out:
# ['xyz', 'pqr', 2535, (6+5j)]

# %%
l2.pop()
# Out:
# (6+5j)

# %%
l2
# Out:
# ['xyz', 'pqr', 2535]

# %%
l2.pop()
l2
# Out:
# ['xyz', 'pqr']

# %%
l2.append(5565)

# %%
l2
# Out:
# ['xyz', 'pqr', 5565]

# %%
l2.insert(1,"hghg")

# %%
l2
# Out:
# ['xyz', 'hghg', 'pqr', 5565]

# %%
l2.insert(3, [32,25,52,25])

# %%
l2
# Out:
# ['xyz', 'hghg', 'pqr', [32, 25, 52, 25], 5565]

# %%
l2[::-1]
# Out:
# [5565, [32, 25, 52, 25], 'pqr', 'hghg', 'xyz']

# %%
l2.reverse()

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ea320d2ace30> in <module>
# ----> 1 l2
#
# NameError: name 'l2' is not defined
